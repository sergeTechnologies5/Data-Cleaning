# %%
import pandas as pd

df_clean = pd.read_csv('data/housing.csv')

df_clean.head()
# Out:
#    Unnamed: 0  0.00632  18.00  2.310  0  0.5380  6.5750  65.20  4.0900  1  \
# 0           0  0.02731    0.0   7.07  0   0.469   6.421   78.9  4.9671  2
# 1           1  0.02729    0.0   7.07  0   0.469   7.185   61.1  4.9671  2
# 2           2  0.03237    0.0   2.18  0   0.458   6.998   45.8  6.0622  3
# 3           3  0.06905    0.0   2.18  0   0.458   7.147   54.2  6.0622  3
# 4           4  0.02985    0.0   2.18  0   0.458   6.430   58.7  6.0622  3
#
#    296.0  15.30  396.90  4.98  24.00
# 0  242.0   17.8  396.90  9.14   21.6
# 1  242.0   17.8  392.83  4.03   34.7
# 2  222.0   18.7  394.63  2.94   33.4
# 3  222.0   18.7  396.90  5.33   36.2
# 4  222.0   18.7  394.12  5.21   28.7

# %%
#download data
#df_clean.to_csv('data/housing.csv')
